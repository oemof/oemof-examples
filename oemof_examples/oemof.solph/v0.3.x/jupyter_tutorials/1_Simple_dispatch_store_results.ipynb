# %% [markdown]
# # Energy system optimisation with oemof - how to collect and store results

# %% [markdown]
# ### Import necessary modules

# %%
import os
import pandas as pd
from oemof.solph import (Sink, Source, Transformer, Bus, Flow, Model,
                         EnergySystem)
import oemof.outputlib as outputlib
import pickle

# %% [markdown]
# ### Specify solver

# %%
solver = 'cbc'

# %% [markdown]
# ### Create an energy system and optimize the dispatch at least costs.

# %%
# initialize and provide data
datetimeindex = pd.date_range('1/1/2016', periods=24*10, freq='H')
energysystem = EnergySystem(timeindex=datetimeindex)
filename = 'input_data.csv'
data = pd.read_csv(filename, sep=",")

# %% [markdown]
# ### Create and add components to energysystem

# %%
# resource buses
bcoal = Bus(label='coal', balanced=False)
bgas = Bus(label='gas', balanced=False)
boil = Bus(label='oil', balanced=False)
blig = Bus(label='lignite', balanced=False)

# electricity and heat
bel = Bus(label='bel')
bth = Bus(label='bth')

energysystem.add(bcoal, bgas, boil, blig, bel, bth)

# %%
# an excess and a shortage variable can help to avoid infeasible problems
energysystem.add(Sink(label='excess_el', inputs={bel: Flow()}))
# shortage_el = Source(label='shortage_el',
#                      outputs={bel: Flow(variable_costs=200)})

# sources
energysystem.add(Source(label='wind', outputs={bel: Flow(
    actual_value=data['wind'], nominal_value=66.3, fixed=True)}))

energysystem.add(Source(label='pv', outputs={bel: Flow(
    actual_value=data['pv'], nominal_value=65.3, fixed=True)}))

# demands (electricity/heat)
energysystem.add(Sink(label='demand_el', inputs={bel: Flow(
    nominal_value=85, actual_value=data['demand_el'], fixed=True)}))

energysystem.add(Sink(label='demand_th',
                 inputs={bth: Flow(nominal_value=40,
                                   actual_value=data['demand_th'],
                                   fixed=True)}))

# %%
# power plants
energysystem.add(Transformer(
    label='pp_coal',
    inputs={bcoal: Flow()},
    outputs={bel: Flow(nominal_value=20.2, variable_costs=25)},
    conversion_factors={bel: 0.39}))

energysystem.add(Transformer(
    label='pp_lig',
    inputs={blig: Flow()},
    outputs={bel: Flow(nominal_value=11.8, variable_costs=19)},
    conversion_factors={bel: 0.41}))

energysystem.add(Transformer(
    label='pp_gas',
    inputs={bgas: Flow()},
    outputs={bel: Flow(nominal_value=41, variable_costs=40)},
    conversion_factors={bel: 0.50}))

energysystem.add(Transformer(
    label='pp_oil',
    inputs={boil: Flow()},
    outputs={bel: Flow(nominal_value=5, variable_costs=50)},
    conversion_factors={bel: 0.28}))

# %%
# combined heat and power plant (chp)

# %%
# heat pump with a coefficient of performance (COP) of 3
b_heat_source = Bus(label='b_heat_source')
energysystem.add(b_heat_source)

energysystem.add(Source(label='heat_source', outputs={b_heat_source: Flow()}))

cop = 3
energysystem.add(Transformer(
    label='heat_pump',
    inputs={bel: Flow(),
            b_heat_source: Flow()},
    outputs={bth: Flow(nominal_value=10)},
    conversion_factors={bel: 1/3, b_heat_source: (cop-1)/cop}))

# %% [markdown]
# ### Optimization

# %%
# create optimization model based on energy_system
optimization_model = Model(energysystem=energysystem)

# solve problem
optimization_model.solve(solver=solver,
                         solve_kwargs={'tee': True, 'keepfiles': False})
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.9.9
# Build Date: Aug 21 2017
#
# command line - /usr/bin/cbc -printingOptions all -import /home/local/RL-INSTITUT/okan.akca/Schreibtisch/oemof-examples/oemof_examples/oemof.solph/v0.3.x/jupyter_tutorials/tmprkmmoipf.pyomo.lp -stat=1 -solve -solu /home/local/RL-INSTITUT/okan.akca/Schreibtisch/oemof-examples/oemof_examples/oemof.solph/v0.3.x/jupyter_tutorials/tmprkmmoipf.pyomo.soln (default strategy 1)
# Option for printingOptions changed from normal to all
# Presolve determined that the problem was infeasible with tolerance of 1e-08
# Presolved model looks infeasible - will use unpresolved
#
#
# Problem has 2161 rows, 3121 columns (960 with objective) and 5041 elements
# There are 1441 singletons with no objective
# Column breakdown:
# 1921 of type 0.0->inf, 1200 of type 0.0->up, 0 of type lo->inf,
# 0 of type lo->up, 0 of type free, 0 of type fixed,
# 0 of type -inf->0.0, 0 of type -inf->up, 0 of type 0.0->1.0
# Row breakdown:
# 1680 of type E 0.0, 1 of type E 1.0, 0 of type E -1.0,
# 480 of type E other, 0 of type G 0.0, 0 of type G 1.0,
# 0 of type G other, 0 of type L 0.0, 0 of type L 1.0,
# 0 of type L other, 0 of type Range 0.0->1.0, 0 of type Range other,
# 0 of type Free
# Presolve determined that the problem was infeasible with tolerance of 1e-08
# Analysis indicates model infeasible or unbounded
# 1 infeasibilities
# Analysis indicates model infeasible or unbounded
# Perturbing problem by 0.001 %% of 31.020891 - largest nonzero change 0.00017470326 (%% 0.00064971419) - largest zero change 4.0993349e-05
# 0  Obj 0 Primal inf 16587.385 (481)
# 118  Obj 250561.11 Primal inf 18057.353 (748)
# 236  Obj 370300.76 Primal inf 17222.743 (891)
# 354  Obj 375234.53 Primal inf 13528.569 (789)
# 472  Obj 375234.53 Primal inf 10135.567 (671)
# 590  Obj 377887.01 Primal inf 6626.2974 (565)
# 708  Obj 377887.01 Primal inf 4681.0714 (447)
# 826  Obj 378139.47 Primal inf 2611.1332 (331)
# 944  Obj 378313.84 Primal inf 2795.735 (463)
# 1062  Obj 379095.72 Primal inf 3173.4718 (582)
# 1180  Obj 382437.17 Primal inf 2889.8592 (563)
# 1298  Obj 388608.84 Primal inf 2566.9642 (533)
# 1416  Obj 393861.11 Primal inf 2131.3518 (487)
# 1528  Obj 398299.71 Primal inf 1559.1183 (406)
# 1537  Obj 398640.16 Primal inf 1524.0527 (401)
# 1586  Obj 399967.63 Primal inf 1301.174 (370)
# 1595  Obj 400237.43 Primal inf 1262.4665 (364)
# 1640  Obj 401801.32 Primal inf 1097.2001 (340)
# 1728  Obj 403717.95 Primal inf 835.67205 (300)
# 1730  Obj 403790.7 Primal inf 829.49178 (299)
# 1769  Obj 405318.29 Primal inf 677.91989 (267)
# 1795  Obj 406490.03 Primal inf 584.18647 (247)
# 1808  Obj 406750.15 Primal inf 523.42352 (234)
# 1830  Obj 406886.15 Primal inf 427.9841 (214)
# 1838  Obj 407157.35 Primal inf 403.97387 (207)
# 1852  Obj 407469.14 Primal inf 370.3152 (198)
# 1861  Obj 407542.09 Primal inf 341.5886 (191)
# 1862  Obj 407542.09 Primal inf 337.47768 (190)
# 1869  Obj 407639.77 Primal inf 321.78395 (186)
# 1877  Obj 407971.33 Primal inf 294.92448 (178)
# 1879  Obj 408097.4 Primal inf 289.4656 (176)
# 1880  Obj 408097.4 Primal inf 285.90566 (175)
# 1881  Obj 408097.4 Primal inf 282.36174 (174)
# 1884  Obj 408182.74 Primal inf 276.05685 (172)
# 1887  Obj 408243.17 Primal inf 266.50962 (169)
# 1891  Obj 408266.17 Primal inf 257.19776 (166)
# 1894  Obj 408287.31 Primal inf 251.44522 (164)
# 1898  Obj 408338.85 Primal inf 244.30064 (162)
# 1901  Obj 408356.77 Primal inf 238.124 (160)
# 1902  Obj 408356.77 Primal inf 235.45699 (159)
# 1903  Obj 408373.05 Primal inf 235.96982 (159)
# 1904  Obj 408373.05 Primal inf 233.08063 (158)
# 1905  Obj 408373.05 Primal inf 230.45638 (157)
# 1906  Obj 408385.07 Primal inf 230.83501 (157)
# 1907  Obj 408396.88 Primal inf 231.20704 (157)
# 1909  Obj 408396.88 Primal inf 228.26951 (155)
# 1910  Obj 408396.88 Primal inf 226.36572 (154)
# 1911  Obj 408401.17 Primal inf 226.38459 (154)
# 1913  Obj 408407.98 Primal inf 225.58346 (153)
# 1914  Obj 408407.98 Primal inf 224.48454 (152)
# 1915  Obj 408413.09 Primal inf 224.64524 (152)
# 1916  Obj 408413.09 Primal inf 223.82288 (151)
# 1917  Obj 408420.61 Primal inf 223.91181 (151)
# 1918  Obj 408420.61 Primal inf 223.35854 (150)
# 1918  Obj 408420.61 Primal inf 223.35854 (150)
# 1918  Obj 408420.61 Primal inf 223.35854 (150)
# 1918  Obj 408420.61 Primal inf 223.35854 (150)
# 1918  Obj 408420.61 Primal inf 223.35854 (150)
# 1918  Obj 408420.61 Primal inf 223.35854 (150)
# 1918  Obj 408418.71 Primal inf 223.35854 (150)
# Primal infeasible - objective value 408418.71
# PrimalInfeasible objective 408418.7113 - 1918 iterations time 0.032
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.04
# Time (Wallclock Seconds):   0.05
#
# Total time (CPU seconds):       0.05   (Wallclock seconds):       0.06
# ERROR:root:Optimization failed with status ok and terminal condition infeasible
# {'Problem': [{'Name': 'unknown', 'Lower bound': -inf, 'Upper bound': inf, 'Number of objectives': 1, 'Number of constraints': 0, 'Number of variables': 0, 'Sense': 'minimize'}], 'Solver': [{'Status': 'ok', 'User time': -1.0, 'Termination condition': 'infeasible', 'Error rc': 0, 'Time': 0.0820760726928711}]}

# %% [markdown]
# ### Write results into energysystem.results object for later

# %%
energysystem.results['main'] = outputlib.processing.results(optimization_model)
energysystem.results['meta'] = outputlib.processing.meta_results(optimization_model)
# Out:
# ERROR:pyomo.core:evaluating expression: No value for uninitialized NumericValue object flow[pp_coal,bel,0]
#     (expression: 25*flow[pp_coal,bel,0] + 25*flow[pp_coal,bel,1] + 25*flow[pp_coal,bel,2] + 25*flow[pp_coal,bel,3] + 25*flow[pp_coal,bel,4] + 25*flow[pp_coal,bel,5] + 25*flow[pp_coal,bel,6] + 25*flow[pp_coal,bel,7] + 25*flow[pp_coal,bel,8] + 25*flow[pp_coal,bel,9] + 25*flow[pp_coal,bel,10] + 25*flow[pp_coal,bel,11] + 25*flow[pp_coal,bel,12] + 25*flow[pp_coal,bel,13] + 25*flow[pp_coal,bel,14] + 25*flow[pp_coal,bel,15] + 25*flow[pp_coal,bel,16] + 25*flow[pp_coal,bel,17] + 25*flow[pp_coal,bel,18] + 25*flow[pp_coal,bel,19] + 25*flow[pp_coal,bel,20] + 25*flow[pp_coal,bel,21] + 25*flow[pp_coal,bel,22] + 25*flow[pp_coal,bel,23] + 25*flow[pp_coal,bel,24] + 25*flow[pp_coal,bel,25] + 25*flow[pp_coal,bel,26] + 25*flow[pp_coal,bel,27] + 25*flow[pp_coal,bel,28] + 25*flow[pp_coal,bel,29] + 25*flow[pp_coal,bel,30] + 25*flow[pp_coal,bel,31] + 25*flow[pp_coal,bel,32] + 25*flow[pp_coal,bel,33] + 25*flow[pp_coal,bel,34] + 25*flow[pp_coal,bel,35] + 25*flow[pp_coal,bel,36] + 25*flow[pp_coal,bel,37] + 25*flow[pp_coal,bel,38] + 25*flow[pp_coal,bel,39] + 25*flow[pp_coal,bel,40] + 25*flow[pp_coal,bel,41] + 25*flow[pp_coal,bel,42] + 25*flow[pp_coal,bel,43] + 25*flow[pp_coal,bel,44] + 25*flow[pp_coal,bel,45] + 25*flow[pp_coal,bel,46] + 25*flow[pp_coal,bel,47] + 25*flow[pp_coal,bel,48] + 25*flow[pp_coal,bel,49] + 25*flow[pp_coal,bel,50] + 25*flow[pp_coal,bel,51] + 25*flow[pp_coal,bel,52] + 25*flow[pp_coal,bel,53] + 25*flow[pp_coal,bel,54] + 25*flow[pp_coal,bel,55] + 25*flow[pp_coal,bel,56] + 25*flow[pp_coal,bel,57] + 25*flow[pp_coal,bel,58] + 25*flow[pp_coal,bel,59] + 25*flow[pp_coal,bel,60] + 25*flow[pp_coal,bel,61] + 25*flow[pp_coal,bel,62] + 25*flow[pp_coal,bel,63] + 25*flow[pp_coal,bel,64] + 25*flow[pp_coal,bel,65] + 25*flow[pp_coal,bel,66] + 25*flow[pp_coal,bel,67] + 25*flow[pp_coal,bel,68] + 25*flow[pp_coal,bel,69] + 25*flow[pp_coal,bel,70] + 25*flow[pp_coal,bel,71] + 25*flow[pp_coal,bel,72] + 25*flow[pp_coal,bel,73] + 25*flow[pp_coal,bel,74] + 25*flow[pp_coal,bel,75] + 25*flow[pp_coal,bel,76] + 25*flow[pp_coal,bel,77] + 25*flow[pp_coal,bel,78] + 25*flow[pp_coal,bel,79] + 25*flow[pp_coal,bel,80] + 25*flow[pp_coal,bel,81] + 25*flow[pp_coal,bel,82] + 25*flow[pp_coal,bel,83] + 25*flow[pp_coal,bel,84] + 25*flow[pp_coal,bel,85] + 25*flow[pp_coal,bel,86] + 25*flow[pp_coal,bel,87] + 25*flow[pp_coal,bel,88] + 25*flow[pp_coal,bel,89] + 25*flow[pp_coal,bel,90] + 25*flow[pp_coal,bel,91] + 25*flow[pp_coal,bel,92] + 25*flow[pp_coal,bel,93] + 25*flow[pp_coal,bel,94] + 25*flow[pp_coal,bel,95] + 25*flow[pp_coal,bel,96] + 25*flow[pp_coal,bel,97] + 25*flow[pp_coal,bel,98] + 25*flow[pp_coal,bel,99] + 25*flow[pp_coal,bel,100] + 25*flow[pp_coal,bel,101] + 25*flow[pp_coal,bel,102] + 25*flow[pp_coal,bel,103] + 25*flow[pp_coal,bel,104] + 25*flow[pp_coal,bel,105] + 25*flow[pp_coal,bel,106] + 25*flow[pp_coal,bel,107] + 25*flow[pp_coal,bel,108] + 25*flow[pp_coal,bel,109] + 25*flow[pp_coal,bel,110] + 25*flow[pp_coal,bel,111] + 25*flow[pp_coal,bel,112] + 25*flow[pp_coal,bel,113] + 25*flow[pp_coal,bel,114] + 25*flow[pp_coal,bel,115] + 25*flow[pp_coal,bel,116] + 25*flow[pp_coal,bel,117] + 25*flow[pp_coal,bel,118] + 25*flow[pp_coal,bel,119] + 25*flow[pp_coal,bel,120] + 25*flow[pp_coal,bel,121] + 25*flow[pp_coal,bel,122] + 25*flow[pp_coal,bel,123] + 25*flow[pp_coal,bel,124] + 25*flow[pp_coal,bel,125] + 25*flow[pp_coal,bel,126] + 25*flow[pp_coal,bel,127] + 25*flow[pp_coal,bel,128] + 25*flow[pp_coal,bel,129] + 25*flow[pp_coal,bel,130] + 25*flow[pp_coal,bel,131] + 25*flow[pp_coal,bel,132] + 25*flow[pp_coal,bel,133] + 25*flow[pp_coal,bel,134] + 25*flow[pp_coal,bel,135] + 25*flow[pp_coal,bel,136] + 25*flow[pp_coal,bel,137] + 25*flow[pp_coal,bel,138] + 25*flow[pp_coal,bel,139] + 25*flow[pp_coal,bel,140] + 25*flow[pp_coal,bel,141] + 25*flow[pp_coal,bel,142] + 25*flow[pp_coal,bel,143] + 25*flow[pp_coal,bel,144] + 25*flow[pp_coal,bel,145] + 25*flow[pp_coal,bel,146] + 25*flow[pp_coal,bel,147] + 25*flow[pp_coal,bel,148] + 25*flow[pp_coal,bel,149] + 25*flow[pp_coal,bel,150] + 25*flow[pp_coal, ...
# ERROR: evaluating expression: No value for uninitialized NumericValue object
#     flow[pp_coal,bel,0]
#         (expression: 25*flow[pp_coal,bel,0] + 25*flow[pp_coal,bel,1] +
#         25*flow[pp_coal,bel,2] + 25*flow[pp_coal,bel,3] +
#         25*flow[pp_coal,bel,4] + 25*flow[pp_coal,bel,5] +
#         25*flow[pp_coal,bel,6] + 25*flow[pp_coal,bel,7] +
#         25*flow[pp_coal,bel,8] + 25*flow[pp_coal,bel,9] +
#         25*flow[pp_coal,bel,10] + 25*flow[pp_coal,bel,11] +
#         25*flow[pp_coal,bel,12] + 25*flow[pp_coal,bel,13] +
#         25*flow[pp_coal,bel,14] + 25*flow[pp_coal,bel,15] +
#         25*flow[pp_coal,bel,16] + 25*flow[pp_coal,bel,17] +
#         25*flow[pp_coal,bel,18] + 25*flow[pp_coal,bel,19] +
#         25*flow[pp_coal,bel,20] + 25*flow[pp_coal,bel,21] +
#         25*flow[pp_coal,bel,22] + 25*flow[pp_coal,bel,23] +
#         25*flow[pp_coal,bel,24] + 25*flow[pp_coal,bel,25] +
#         25*flow[pp_coal,bel,26] + 25*flow[pp_coal,bel,27] +
#         25*flow[pp_coal,bel,28] + 25*flow[pp_coal,bel,29] +
#         25*flow[pp_coal,bel,30] + 25*flow[pp_coal,bel,31] +
#         25*flow[pp_coal,bel,32] + 25*flow[pp_coal,bel,33] +
#         25*flow[pp_coal,bel,34] + 25*flow[pp_coal,bel,35] +
#         25*flow[pp_coal,bel,36] + 25*flow[pp_coal,bel,37] +
#         25*flow[pp_coal,bel,38] + 25*flow[pp_coal,bel,39] +
#         25*flow[pp_coal,bel,40] + 25*flow[pp_coal,bel,41] +
#         25*flow[pp_coal,bel,42] + 25*flow[pp_coal,bel,43] +
#         25*flow[pp_coal,bel,44] + 25*flow[pp_coal,bel,45] +
#         25*flow[pp_coal,bel,46] + 25*flow[pp_coal,bel,47] +
#         25*flow[pp_coal,bel,48] + 25*flow[pp_coal,bel,49] +
#         25*flow[pp_coal,bel,50] + 25*flow[pp_coal,bel,51] +
#         25*flow[pp_coal,bel,52] + 25*flow[pp_coal,bel,53] +
#         25*flow[pp_coal,bel,54] + 25*flow[pp_coal,bel,55] +
#         25*flow[pp_coal,bel,56] + 25*flow[pp_coal,bel,57] +
#         25*flow[pp_coal,bel,58] + 25*flow[pp_coal,bel,59] +
#         25*flow[pp_coal,bel,60] + 25*flow[pp_coal,bel,61] +
#         25*flow[pp_coal,bel,62] + 25*flow[pp_coal,bel,63] +
#         25*flow[pp_coal,bel,64] + 25*flow[pp_coal,bel,65] +
#         25*flow[pp_coal,bel,66] + 25*flow[pp_coal,bel,67] +
#         25*flow[pp_coal,bel,68] + 25*flow[pp_coal,bel,69] +
#         25*flow[pp_coal,bel,70] + 25*flow[pp_coal,bel,71] +
#         25*flow[pp_coal,bel,72] + 25*flow[pp_coal,bel,73] +
#         25*flow[pp_coal,bel,74] + 25*flow[pp_coal,bel,75] +
#         25*flow[pp_coal,bel,76] + 25*flow[pp_coal,bel,77] +
#         25*flow[pp_coal,bel,78] + 25*flow[pp_coal,bel,79] +
#         25*flow[pp_coal,bel,80] + 25*flow[pp_coal,bel,81] +
#         25*flow[pp_coal,bel,82] + 25*flow[pp_coal,bel,83] +
#         25*flow[pp_coal,bel,84] + 25*flow[pp_coal,bel,85] +
#         25*flow[pp_coal,bel,86] + 25*flow[pp_coal,bel,87] +
#         25*flow[pp_coal,bel,88] + 25*flow[pp_coal,bel,89] +
#         25*flow[pp_coal,bel,90] + 25*flow[pp_coal,bel,91] +
#         25*flow[pp_coal,bel,92] + 25*flow[pp_coal,bel,93] +
#         25*flow[pp_coal,bel,94] + 25*flow[pp_coal,bel,95] +
#         25*flow[pp_coal,bel,96] + 25*flow[pp_coal,bel,97] +
#         25*flow[pp_coal,bel,98] + 25*flow[pp_coal,bel,99] +
#         25*flow[pp_coal,bel,100] + 25*flow[pp_coal,bel,101] +
#         25*flow[pp_coal,bel,102] + 25*flow[pp_coal,bel,103] +
#         25*flow[pp_coal,bel,104] + 25*flow[pp_coal,bel,105] +
#         25*flow[pp_coal,bel,106] + 25*flow[pp_coal,bel,107] +
#         25*flow[pp_coal,bel,108] + 25*flow[pp_coal,bel,109] +
#         25*flow[pp_coal,bel,110] + 25*flow[pp_coal,bel,111] +
#         25*flow[pp_coal,bel,112] + 25*flow[pp_coal,bel,113] +
#         25*flow[pp_coal,bel,114] + 25*flow[pp_coal,bel,115] +
#         25*flow[pp_coal,bel,116] + 25*flow[pp_coal,bel,117] +
#         25*flow[pp_coal,bel,118] + 25*flow[pp_coal,bel,119] +
#         25*flow[pp_coal,bel,120] + 25*flow[pp_coal,bel,121] +
#         25*flow[pp_coal,bel,122] + 25*flow[pp_coal,bel,123] +
#         25*flow[pp_coal,bel,124] + 25*flow[pp_coal,bel,125] +
#         25*flow[pp_coal,bel,126] + 25*flow[pp_coal,bel,127] +
#         25*flow[pp_coal,bel,128] + 25*flow[pp_coal,bel,129] +
#         25*flow[pp_coal,bel,130] + 25*flow[pp_coal,bel,131] +
#         25*flow[pp_coal,bel,132] + 25*flow[pp_coal,bel,133] +
#         25*flow[pp_coal,bel,134] + 25*flow[pp_coal,bel,135] +
#         25*flow[pp_coal,bel,136] + 25*flow[pp_coal,bel,137] +
#         25*flow[pp_coal,bel,138] + 25*flow[pp_coal,bel,139] +
#         25*flow[pp_coal,bel,140] + 25*flow[pp_coal,bel,141] +
#         25*flow[pp_coal,bel,142] + 25*flow[pp_coal,bel,143] +
#         25*flow[pp_coal,bel,144] + 25*flow[pp_coal,bel,145] +
#         25*flow[pp_coal,bel,146] + 25*flow[pp_coal,bel,147] +
#         25*flow[pp_coal,bel,148] + 25*flow[pp_coal,bel,149] +
#         25*flow[pp_coal,bel,150] + 25*flow[pp_coal,bel,151] +
#         25*flow[pp_coal,bel,152] + 25*flow[pp_coal,bel,153] +
#         25*flow[pp_coal,bel,154] + 25*flow[pp_coal,bel,155] +
#         25*flow[pp_coal,bel,156] + 25*flow[pp_coal,bel,157] +
#         25*flow[pp_coal,bel,158] + 25*flow[pp_coal,bel,159] +
#         25*flow[pp_coal,bel,160] + 25*flow[pp_coal,bel,161] +
#         25*flow[pp_coal,bel,162] + 25*flow[pp_coal,bel,163] +
#         25*flow[pp_coal,bel,164] + 25*flow[pp_coal,bel,165] +
#         25*flow[pp_coal,bel,166] + 25*flow[pp_coal,bel,167] +
#         25*flow[pp_coal,bel,168] + 25*flow[pp_coal,bel,169] +
#         25*flow[pp_coal,bel,170] + 25*flow[pp_coal,bel,171] +
#         25*flow[pp_coal,bel,172] + 25*flow[pp_coal,bel,173] +
#         25*flow[pp_coal,bel,174] + 25*flow[pp_coal,bel,175] +
#         25*flow[pp_coal,bel,176] + 25*flow[pp_coal,bel,177] +
#         25*flow[pp_coal,bel,178] + 25*flow[pp_coal,bel,179] +
#         25*flow[pp_coal,bel,180] + 25*flow[pp_coal,bel,181] +
#         25*flow[pp_coal,bel,182] + 25*flow[pp_coal,bel,183] +
#         25*flow[pp_coal,bel,184] + 25*flow[pp_coal,bel,185] +
#         25*flow[pp_coal,bel,186] + 25*flow[pp_coal,bel,187] +
#         25*flow[pp_coal,bel,188] + 25*flow[pp_coal,bel,189] +
#         25*flow[pp_coal,bel,190] + 25*flow[pp_coal,bel,191] +
#         25*flow[pp_coal,bel,192] + 25*flow[pp_coal,bel,193] +
#         25*flow[pp_coal,bel,194] + 25*flow[pp_coal,bel,195] +
#         25*flow[pp_coal,bel,196] + 25*flow[pp_coal,bel,197] +
#         25*flow[pp_coal,bel,198] + 25*flow[pp_coal,bel,199] +
#         25*flow[pp_coal,bel,200] + 25*flow[pp_coal,bel,201] +
#         25*flow[pp_coal,bel,202] + 25*flow[pp_coal,bel,203] +
#         25*flow[pp_coal,bel,204] + 25*flow[pp_coal,bel,205] +
#         25*flow[pp_coal,bel,206] + 25*flow[pp_coal,bel,207] +
#         25*flow[pp_coal,bel,208] + 25*flow[pp_coal,bel,209] +
#         25*flow[pp_coal,bel,210] + 25*flow[pp_coal,bel,211] +
#         25*flow[pp_coal,bel,212] + 25*flow[pp_coal,bel,213] +
#         25*flow[pp_coal,bel,214] + 25*flow[pp_coal,bel,215] +
#         25*flow[pp_coal,bel,216] + 25*flow[pp_coal,bel,217] +
#         25*flow[pp_coal,bel,218] + 25*flow[pp_coal,bel,219] +
#         25*flow[pp_coal,bel,220] + 25*flow[pp_coal,bel,221] +
#         25*flow[pp_coal,bel,222] + 25*flow[pp_coal,bel,223] +
#         25*flow[pp_coal,bel,224] + 25*flow[pp_coal,bel,225] +
#         25*flow[pp_coal,bel,226] + 25*flow[pp_coal,bel,227] +
#         25*flow[pp_coal,bel,228] + 25*flow[pp_coal,bel,229] +
#         25*flow[pp_coal,bel,230] + 25*flow[pp_coal,bel,231] +
#         25*flow[pp_coal,bel,232] + 25*flow[pp_coal,bel,233] +
#         25*flow[pp_coal,bel,234] + 25*flow[pp_coal,bel,235] +
#         25*flow[pp_coal,bel,236] + 25*flow[pp_coal,bel,237] +
#         25*flow[pp_coal,bel,238] + 25*flow[pp_coal,bel,239] +
#         19*flow[pp_lig,bel,0] + 19*flow[pp_lig,bel,1] + 19*flow[pp_lig,bel,2]
#         + 19*flow[pp_lig,bel,3] + 19*flow[pp_lig,bel,4] +
#         19*flow[pp_lig,bel,5] + 19*flow[pp_lig,bel,6] + 19*flow[pp_lig,bel,7]
#         + 19*flow[pp_lig,bel,8] + 19*flow[pp_lig,bel,9] +
#         19*flow[pp_lig,bel,10] + 19*flow[pp_lig,bel,11] +
#         19*flow[pp_lig,bel,12] + 19*flow[pp_lig,bel,13] +
#         19*flow[pp_lig,bel,14] + 19*flow[pp_lig,bel,15] +
#         19*flow[pp_lig,bel,16] + 19*flow[pp_lig,bel,17] +
#         19*flow[pp_lig,bel,18] + 19*flow[pp_lig,bel,19] +
#         19*flow[pp_lig,bel,20] + 19*flow[pp_lig,bel,21] +
#         19*flow[pp_lig,bel,22] + 19*flow[pp_lig,bel,23] +
#         19*flow[pp_lig,bel,24] + 19*flow[pp_lig,bel,25] +
#         19*flow[pp_lig,bel,26] + 19*flow[pp_lig,bel,27] +
#         19*flow[pp_lig,bel,28] + 19*flow[pp_lig,bel,29] +
#         19*flow[pp_lig,bel,30] + 19*flow[pp_lig,bel,31] +
#         19*flow[pp_lig,bel,32] + 19*flow[pp_lig,bel,33] +
#         19*flow[pp_lig,bel,34] + 19*flow[pp_lig,bel,35] +
#         19*flow[pp_lig,bel,36] + 19*flow[pp_lig,bel,37] +
#         19*flow[pp_lig,bel,38] + 19*flow[pp_lig,bel,39] +
#         19*flow[pp_lig,bel,40] + 19*flow[pp_lig,bel,41] +
#         19*flow[pp_lig,bel,42] + 19*flow[pp_lig,bel,43] +
#         19*flow[pp_lig,bel,44] + 19*flow[pp_lig,bel,45] +
#         19*flow[pp_lig,bel,46] + 19*flow[pp_lig,bel,47] +
#         19*flow[pp_lig,bel,48] + 19*flow[pp_lig,bel,49] +
#         19*flow[pp_lig,bel,50] + 19*flow[pp_lig,bel,51] +
#         19*flow[pp_lig,bel,52] + 19*flow[pp_lig,bel,53] +
#         19*flow[pp_lig,bel,54] + 19*flow[pp_lig,bel,55] +
#         19*flow[pp_lig,bel,56] + 19*flow[pp_lig,bel,57] +
#         19*flow[pp_lig,bel,58] + 19*flow[pp_lig,bel,59] +
#         19*flow[pp_lig,bel,60] + 19*flow[pp_lig,bel,61] +
#         19*flow[pp_lig,bel,62] + 19*flow[pp_lig,bel,63] +
#         19*flow[pp_lig,bel,64] + 19*flow[pp_lig,bel,65] +
#         19*flow[pp_lig,bel,66] + 19*flow[pp_lig,bel,67] +
#         19*flow[pp_lig,bel,68] + 19*flow[pp_lig,bel,69] +
#         19*flow[pp_lig,bel,70] + 19*flow[pp_lig,bel,71] +
#         19*flow[pp_lig,bel,72] + 19*flow[pp_lig,bel,73] +
#         19*flow[pp_lig,bel,74] + 19*flow[pp_lig,bel,75] +
#         19*flow[pp_lig,bel,76] + 19*flow[pp_lig,bel,77] +
#         19*flow[pp_lig,bel,78] + 19*flow[pp_lig,bel,79] +
#         19*flow[pp_lig,bel,80] + 19*flow[pp_lig,bel,81] +
#         19*flow[pp_lig,bel,82] + 19*flow[pp_lig,bel,83] +
#         19*flow[pp_lig,bel,84] + 19*flow[pp_lig,bel,85] +
#         19*flow[pp_lig,bel,86] + 19*flow[pp_lig,bel,87] +
#         19*flow[pp_lig,bel,88] + 19*flow[pp_lig,bel,89] +
#         19*flow[pp_lig,bel,90] + 19*flow[pp_lig,bel,91] +
#         19*flow[pp_lig,bel,92] + 19*flow[pp_lig,bel,93] +
#         19*flow[pp_lig,bel,94] + 19*flow[pp_lig,bel,95] +
#         19*flow[pp_lig,bel,96] + 19*flow[pp_lig,bel,97] +
#         19*flow[pp_lig,bel,98] + 19*flow[pp_lig,bel,99] +
#         19*flow[pp_lig,bel,100] + 19*flow[pp_lig,bel,101] +
#         19*flow[pp_lig,bel,102] + 19*flow[pp_lig,bel,103] +
#         19*flow[pp_lig,bel,104] + 19*flow[pp_lig,bel,105] +
#         19*flow[pp_lig,bel,106] + 19*flow[pp_lig,bel,107] +
#         19*flow[pp_lig,bel,108] + 19*flow[pp_lig,bel,109] +
#         19*flow[pp_lig,bel,110] + 19*flow[pp_lig,bel,111] +
#         19*flow[pp_lig,bel,112] + 19*flow[pp_lig,bel,113] +
#         19*flow[pp_lig,bel,114] + 19*flow[pp_lig,bel,115] +
#         19*flow[pp_lig,bel,116] + 19*flow[pp_lig,bel,117] +
#         19*flow[pp_lig,bel,118] + 19*flow[pp_lig,bel,119] +
#         19*flow[pp_lig,bel,120] + 19*flow[pp_lig,bel,121] +
#         19*flow[pp_lig,bel,122] + 19*flow[pp_lig,bel,123] +
#         19*flow[pp_lig,bel,124] + 19*flow[pp_lig,bel,125] +
#         19*flow[pp_lig,bel,126] + 19*flow[pp_lig,bel,127] +
#         19*flow[pp_lig,bel,128] + 19*flow[pp_lig,bel,129] +
#         19*flow[pp_lig,bel,130] + 19*flow[pp_lig,bel,131] +
#         19*flow[pp_lig,bel,132] + 19*flow[pp_lig,bel,133] +
#         19*flow[pp_lig,bel,134] + 19*flow[pp_lig,bel,135] +
#         19*flow[pp_lig,bel,136] + 19*flow[pp_lig,bel,137] +
#         19*flow[pp_lig,bel,138] + 19*flow[pp_lig,bel,139] +
#         19*flow[pp_lig,bel,140] + 19*flow[pp_lig,bel,141] +
#         19*flow[pp_lig,bel,142] + 19*flow[pp_lig,bel,143] +
#         19*flow[pp_lig,bel,144] + 19*flow[pp_lig,bel,145] +
#         19*flow[pp_lig,bel,146] + 19*flow[pp_lig,bel,147] +
#         19*flow[pp_lig,bel,148] + 19*flow[pp_lig,bel,149] +
#         19*flow[pp_lig,bel,150] + 19*flow[pp_lig,bel,151] +
#         19*flow[pp_lig,bel,152] + 19*flow[pp_lig,bel,153] +
#         19*flow[pp_lig,bel,154] + 19*flow[pp_lig,bel,155] +
#         19*flow[pp_lig,bel,156] + 19*flow[pp_lig,bel,157] +
#         19*flow[pp_lig,bel,158] + 19*flow[pp_lig,bel,159] +
#         19*flow[pp_lig,bel,160] + 19*flow[pp_lig,bel,161] +
#         19*flow[pp_lig,bel,162] + 19*flow[pp_lig,bel,163] +
#         19*flow[pp_lig,bel,164] + 19*flow[pp_lig,bel,165] +
#         19*flow[pp_lig,bel,166] + 19*flow[pp_lig,bel,167] +
#         19*flow[pp_lig,bel,168] + 19*flow[pp_lig,bel,169] +
#         19*flow[pp_lig,bel,170] + 19*flow[pp_lig,bel,171] +
#         19*flow[pp_lig,bel,172] + 19*flow[pp_lig,bel,173] +
#         19*flow[pp_lig,bel,174] + 19*flow[pp_lig,bel,175] +
#         19*flow[pp_lig,bel,176] + 19*flow[pp_lig,bel,177] +
#         19*flow[pp_lig,bel,178] + 19*flow[pp_lig,bel,179] +
#         19*flow[pp_lig,bel,180] + 19*flow[pp_lig,bel,181] +
#         19*flow[pp_lig,bel,182] + 19*flow[pp_lig,bel,183] +
#         19*flow[pp_lig,bel,184] + 19*flow[pp_lig,bel,185] +
#         19*flow[pp_lig,bel,186] + 19*flow[pp_lig,bel,187] +
#         19*flow[pp_lig,bel,188] + 19*flow[pp_lig,bel,189] +
#         19*flow[pp_lig,bel,190] + 19*flow[pp_lig,bel,191] +
#         19*flow[pp_lig,bel,192] + 19*flow[pp_lig,bel,193] +
#         19*flow[pp_lig,bel,194] + 19*flow[pp_lig,bel,195] +
#         19*flow[pp_lig,bel,196] + 19*flow[pp_lig,bel,197] +
#         19*flow[pp_lig,bel,198] + 19*flow[pp_lig,bel,199] +
#         19*flow[pp_lig,bel,200] + 19*flow[pp_lig,bel,201] +
#         19*flow[pp_lig,bel,202] + 19*flow[pp_lig,bel,203] +
#         19*flow[pp_lig,bel,204] + 19*flow[pp_lig,bel,205] +
#         19*flow[pp_lig,bel,206] + 19*flow[pp_lig,bel,207] +
#         19*flow[pp_lig,bel,208] + 19*flow[pp_lig,bel,209] +
#         19*flow[pp_lig,bel,210] + 19*flow[pp_lig,bel,211] +
#         19*flow[pp_lig,bel,212] + 19*flow[pp_lig,bel,213] +
#         19*flow[pp_lig,bel,214] + 19*flow[pp_lig,bel,215] +
#         19*flow[pp_lig,bel,216] + 19*flow[pp_lig,bel,217] +
#         19*flow[pp_lig,bel,218] + 19*flow[pp_lig,bel,219] +
#         19*flow[pp_lig,bel,220] + 19*flow[pp_lig,bel,221] +
#         19*flow[pp_lig,bel,222] + 19*flow[pp_lig,bel,223] +
#         19*flow[pp_lig,bel,224] + 19*flow[pp_lig,bel,225] +
#         19*flow[pp_lig,bel,226] + 19*flow[pp_lig,bel,227] +
#         19*flow[pp_lig,bel,228] + 19*flow[pp_lig,bel,229] +
#         19*flow[pp_lig,bel,230] + 19*flow[pp_lig,bel,231] +
#         19*flow[pp_lig,bel,232] + 19*flow[pp_lig,bel,233] +
#         19*flow[pp_lig,bel,234] + 19*flow[pp_lig,bel,235] +
#         19*flow[pp_lig,bel,236] + 19*flow[pp_lig,bel,237] +
#         19*flow[pp_lig,bel,238] + 19*flow[pp_lig,bel,239] +
#         40*flow[pp_gas,bel,0] + 40*flow[pp_gas,bel,1] + 40*flow[pp_gas,bel,2]
#         + 40*flow[pp_gas,bel,3] + 40*flow[pp_gas,bel,4] +
#         40*flow[pp_gas,bel,5] + 40*flow[pp_gas,bel,6] + 40*flow[pp_gas,bel,7]
#         + 40*flow[pp_gas,bel,8] + 40*flow[pp_gas,bel,9] +
#         40*flow[pp_gas,bel,10] + 40*flow[pp_gas,bel,11] +
#         40*flow[pp_gas,bel,12] + 40*flow[pp_gas,bel,13] +
#         40*flow[pp_gas,bel,14] + 40*flow[pp_gas,bel,15] +
#         40*flow[pp_gas,bel,16] + 40*flow[pp_gas,bel,17] +
#         40*flow[pp_gas,bel,18] + 40*flow[pp_gas,bel,19] +
#         40*flow[pp_gas,bel,20] + 40*flow[pp_gas,bel,21] +
#         40*flow[pp_gas,bel,22] + 40*flow[pp_gas,bel,23] +
#         40*flow[pp_gas,bel,24] + 40*flow[pp_gas,bel,25] +
#         40*flow[pp_gas,bel,26] + 40*flow[pp_gas,bel,27] +
#         40*flow[pp_gas,bel,28] + 40*flow[pp_gas,bel,29] +
#         40*flow[pp_gas,bel,30] + 40*flow[pp_gas,bel,31] +
#         40*flow[pp_gas,bel,32] + 40*flow[pp_gas,bel,33] +
#         40*flow[pp_gas,bel,34] + 40*flow[pp_gas,bel,35] +
#         40*flow[pp_gas,bel,36] + 40*flow[pp_gas,bel,37] +
#         40*flow[pp_gas,bel,38] + 40*flow[pp_gas,bel,39] +
#         40*flow[pp_gas,bel,40] + 40*flow[pp_gas,bel,41] +
#         40*flow[pp_gas,bel,42] + 40*flow[pp_gas,bel,43] +
#         40*flow[pp_gas,bel,44] + 40*flow[pp_gas,bel,45] +
#         40*flow[pp_gas,bel,46] + 40*flow[pp_gas,bel,47] +
#         40*flow[pp_gas,bel,48] + 40*flow[pp_gas,bel,49] +
#         40*flow[pp_gas,bel,50] + 40*flow[pp_gas,bel,51] +
#         40*flow[pp_gas,bel,52] + 40*flow[pp_gas,bel,53] +
#         40*flow[pp_gas,bel,54] + 40*flow[pp_gas,bel,55] +
#         40*flow[pp_gas,bel,56] + 40*flow[pp_gas,bel,57] +
#         40*flow[pp_gas,bel,58] + 40*flow[pp_gas,bel,59] +
#         40*flow[pp_gas,bel,60] + 40*flow[pp_gas,bel,61] +
#         40*flow[pp_gas,bel,62] + 40*flow[pp_gas,bel,63] +
#         40*flow[pp_gas,bel,64] + 40*flow[pp_gas,bel,65] +
#         40*flow[pp_gas,bel,66] + 40*flow[pp_gas,bel,67] +
#         40*flow[pp_gas,bel,68] + 40*flow[pp_gas,bel,69] +
#         40*flow[pp_gas,bel,70] + 40*flow[pp_gas,bel,71] +
#         40*flow[pp_gas,bel,72] + 40*flow[pp_gas,bel,73] +
#         40*flow[pp_gas,bel,74] + 40*flow[pp_gas,bel,75] +
#         40*flow[pp_gas,bel,76] + 40*flow[pp_gas,bel,77] +
#         40*flow[pp_gas,bel,78] + 40*flow[pp_gas,bel,79] +
#         40*flow[pp_gas,bel,80] + 40*flow[pp_gas,bel,81] +
#         40*flow[pp_gas,bel,82] + 40*flow[pp_gas,bel,83] +
#         40*flow[pp_gas,bel,84] + 40*flow[pp_gas,bel,85] +
#         40*flow[pp_gas,bel,86] + 40*flow[pp_gas,bel,87] +
#         40*flow[pp_gas,bel,88] + 40*flow[pp_gas,bel,89] +
#         40*flow[pp_gas,bel,90] + 40*flow[pp_gas,bel,91] +
#         40*flow[pp_gas,bel,92] + 40*flow[pp_gas,bel,93] +
#         40*flow[pp_gas,bel,94] + 40*flow[pp_gas,bel,95] +
#         40*flow[pp_gas,bel,96] + 40*flow[pp_gas,bel,97] +
#         40*flow[pp_gas,bel,98] + 40*flow[pp_gas,bel,99] +
#         40*flow[pp_gas,bel,100] + 40*flow[pp_gas,bel,101] +
#         40*flow[pp_gas,bel,102] + 40*flow[pp_gas,bel,103] +
#         40*flow[pp_gas,bel,104] + 40*flow[pp_gas,bel,105] +
#         40*flow[pp_gas,bel,106] + 40*flow[pp_gas,bel,107] +
#         40*flow[pp_gas,bel,108] + 40*flow[pp_gas,bel,109] +
#         40*flow[pp_gas,bel,110] + 40*flow[pp_gas,bel,111] +
#         40*flow[pp_gas,bel,112] + 40*flow[pp_gas,bel,113] +
#         40*flow[pp_gas,bel,114] + 40*flow[pp_gas,bel,115] +
#         40*flow[pp_gas,bel,116] + 40*flow[pp_gas,bel,117] +
#         40*flow[pp_gas,bel,118] + 40*flow[pp_gas,bel,119] +
#         40*flow[pp_gas,bel,120] + 40*flow[pp_gas,bel,121] +
#         40*flow[pp_gas,bel,122] + 40*flow[pp_gas,bel,123] +
#         40*flow[pp_gas,bel,124] + 40*flow[pp_gas,bel,125] +
#         40*flow[pp_gas,bel,126] + 40*flow[pp_gas,bel,127] +
#         40*flow[pp_gas,bel,128] + 40*flow[pp_gas,bel,129] +
#         40*flow[pp_gas,bel,130] + 40*flow[pp_gas,bel,131] +
#         40*flow[pp_gas,bel,132] + 40*flow[pp_gas,bel,133] +
#         40*flow[pp_gas,bel,134] + 40*flow[pp_gas,bel,135] +
#         40*flow[pp_gas,bel,136] + 40*flow[pp_gas,bel,137] +
#         40*flow[pp_gas,bel,138] + 40*flow[pp_gas,bel,139] +
#         40*flow[pp_gas,bel,140] + 40*flow[pp_gas,bel,141] +
#         40*flow[pp_gas,bel,142] + 40*flow[pp_gas,bel,143] +
#         40*flow[pp_gas,bel,144] + 40*flow[pp_gas,bel,145] +
#         40*flow[pp_gas,bel,146] + 40*flow[pp_gas,bel,147] +
#         40*flow[pp_gas,bel,148] + 40*flow[pp_gas,bel,149] +
#         40*flow[pp_gas,bel,150] + 40*flow[pp_gas,bel,151] +
#         40*flow[pp_gas,bel,152] + 40*flow[pp_gas,bel,153] +
#         40*flow[pp_gas,bel,154] + 40*flow[pp_gas,bel,155] +
#         40*flow[pp_gas,bel,156] + 40*flow[pp_gas,bel,157] +
#         40*flow[pp_gas,bel,158] + 40*flow[pp_gas,bel,159] +
#         40*flow[pp_gas,bel,160] + 40*flow[pp_gas,bel,161] +
#         40*flow[pp_gas,bel,162] + 40*flow[pp_gas,bel,163] +
#         40*flow[pp_gas,bel,164] + 40*flow[pp_gas,bel,165] +
#         40*flow[pp_gas,bel,166] + 40*flow[pp_gas,bel,167] +
#         40*flow[pp_gas,bel,168] + 40*flow[pp_gas,bel,169] +
#         40*flow[pp_gas,bel,170] + 40*flow[pp_gas,bel,171] +
#         40*flow[pp_gas,bel,172] + 40*flow[pp_gas,bel,173] +
#         40*flow[pp_gas,bel,174] + 40*flow[pp_gas,bel,175] +
#         40*flow[pp_gas,bel,176] + 40*flow[pp_gas,bel,177] +
#         40*flow[pp_gas,bel,178] + 40*flow[pp_gas,bel,179] +
#         40*flow[pp_gas,bel,180] + 40*flow[pp_gas,bel,181] +
#         40*flow[pp_gas,bel,182] + 40*flow[pp_gas,bel,183] +
#         40*flow[pp_gas,bel,184] + 40*flow[pp_gas,bel,185] +
#         40*flow[pp_gas,bel,186] + 40*flow[pp_gas,bel,187] +
#         40*flow[pp_gas,bel,188] + 40*flow[pp_gas,bel,189] +
#         40*flow[pp_gas,bel,190] + 40*flow[pp_gas,bel,191] +
#         40*flow[pp_gas,bel,192] + 40*flow[pp_gas,bel,193] +
#         40*flow[pp_gas,bel,194] + 40*flow[pp_gas,bel,195] +
#         40*flow[pp_gas,bel,196] + 40*flow[pp_gas,bel,197] +
#         40*flow[pp_gas,bel,198] + 40*flow[pp_gas,bel,199] +
#         40*flow[pp_gas,bel,200] + 40*flow[pp_gas,bel,201] +
#         40*flow[pp_gas,bel,202] + 40*flow[pp_gas,bel,203] +
#         40*flow[pp_gas,bel,204] + 40*flow[pp_gas,bel,205] +
#         40*flow[pp_gas,bel,206] + 40*flow[pp_gas,bel,207] +
#         40*flow[pp_gas,bel,208] + 40*flow[pp_gas,bel,209] +
#         40*flow[pp_gas,bel,210] + 40*flow[pp_gas,bel,211] +
#         40*flow[pp_gas,bel,212] + 40*flow[pp_gas,bel,213] +
#         40*flow[pp_gas,bel,214] + 40*flow[pp_gas,bel,215] +
#         40*flow[pp_gas,bel,216] + 40*flow[pp_gas,bel,217] +
#         40*flow[pp_gas,bel,218] + 40*flow[pp_gas,bel,219] +
#         40*flow[pp_gas,bel,220] + 40*flow[pp_gas,bel,221] +
#         40*flow[pp_gas,bel,222] + 40*flow[pp_gas,bel,223] +
#         40*flow[pp_gas,bel,224] + 40*flow[pp_gas,bel,225] +
#         40*flow[pp_gas,bel,226] + 40*flow[pp_gas,bel,227] +
#         40*flow[pp_gas,bel,228] + 40*flow[pp_gas,bel,229] +
#         40*flow[pp_gas,bel,230] + 40*flow[pp_gas,bel,231] +
#         40*flow[pp_gas,bel,232] + 40*flow[pp_gas,bel,233] +
#         40*flow[pp_gas,bel,234] + 40*flow[pp_gas,bel,235] +
#         40*flow[pp_gas,bel,236] + 40*flow[pp_gas,bel,237] +
#         40*flow[pp_gas,bel,238] + 40*flow[pp_gas,bel,239] +
#         50*flow[pp_oil,bel,0] + 50*flow[pp_oil,bel,1] + 50*flow[pp_oil,bel,2]
#         + 50*flow[pp_oil,bel,3] + 50*flow[pp_oil,bel,4] +
#         50*flow[pp_oil,bel,5] + 50*flow[pp_oil,bel,6] + 50*flow[pp_oil,bel,7]
#         + 50*flow[pp_oil,bel,8] + 50*flow[pp_oil,bel,9] +
#         50*flow[pp_oil,bel,10] + 50*flow[pp_oil,bel,11] +
#         50*flow[pp_oil,bel,12] + 50*flow[pp_oil,bel,13] +
#         50*flow[pp_oil,bel,14] + 50*flow[pp_oil,bel,15] +
#         50*flow[pp_oil,bel,16] + 50*flow[pp_oil,bel,17] +
#         50*flow[pp_oil,bel,18] + 50*flow[pp_oil,bel,19] +
#         50*flow[pp_oil,bel,20] + 50*flow[pp_oil,bel,21] +
#         50*flow[pp_oil,bel,22] + 50*flow[pp_oil,bel,23] +
#         50*flow[pp_oil,bel,24] + 50*flow[pp_oil,bel,25] +
#         50*flow[pp_oil,bel,26] + 50*flow[pp_oil,bel,27] +
#         50*flow[pp_oil,bel,28] + 50*flow[pp_oil,bel,29] +
#         50*flow[pp_oil,bel,30] + 50*flow[pp_oil,bel,31] +
#         50*flow[pp_oil,bel,32] + 50*flow[pp_oil,bel,33] +
#         50*flow[pp_oil,bel,34] + 50*flow[pp_oil,bel,35] +
#         50*flow[pp_oil,bel,36] + 50*flow[pp_oil,bel,37] +
#         50*flow[pp_oil,bel,38] + 50*flow[pp_oil,bel,39] +
#         50*flow[pp_oil,bel,40] + 50*flow[pp_oil,bel,41] +
#         50*flow[pp_oil,bel,42] + 50*flow[pp_oil,bel,43] +
#         50*flow[pp_oil,bel,44] + 50*flow[pp_oil,bel,45] +
#         50*flow[pp_oil,bel,46] + 50*flow[pp_oil,bel,47] +
#         50*flow[pp_oil,bel,48] + 50*flow[pp_oil,bel,49] +
#         50*flow[pp_oil,bel,50] + 50*flow[pp_oil,bel,51] +
#         50*flow[pp_oil,bel,52] + 50*flow[pp_oil,bel,53] +
#         50*flow[pp_oil,bel,54] + 50*flow[pp_oil,bel,55] +
#         50*flow[pp_oil,bel,56] + 50*flow[pp_oil,bel,57] +
#         50*flow[pp_oil,bel,58] + 50*flow[pp_oil,bel,59] +
#         50*flow[pp_oil,bel,60] + 50*flow[pp_oil,bel,61] +
#         50*flow[pp_oil,bel,62] + 50*flow[pp_oil,bel,63] +
#         50*flow[pp_oil,bel,64] + 50*flow[pp_oil,bel,65] +
#         50*flow[pp_oil,bel,66] + 50*flow[pp_oil,bel,67] +
#         50*flow[pp_oil,bel,68] + 50*flow[pp_oil,bel,69] +
#         50*flow[pp_oil,bel,70] + 50*flow[pp_oil,bel,71] +
#         50*flow[pp_oil,bel,72] + 50*flow[pp_oil,bel,73] +
#         50*flow[pp_oil,bel,74] + 50*flow[pp_oil,bel,75] +
#         50*flow[pp_oil,bel,76] + 50*flow[pp_oil,bel,77] +
#         50*flow[pp_oil,bel,78] + 50*flow[pp_oil,bel,79] +
#         50*flow[pp_oil,bel,80] + 50*flow[pp_oil,bel,81] +
#         50*flow[pp_oil,bel,82] + 50*flow[pp_oil,bel,83] +
#         50*flow[pp_oil,bel,84] + 50*flow[pp_oil,bel,85] +
#         50*flow[pp_oil,bel,86] + 50*flow[pp_oil,bel,87] +
#         50*flow[pp_oil,bel,88] + 50*flow[pp_oil,bel,89] +
#         50*flow[pp_oil,bel,90] + 50*flow[pp_oil,bel,91] +
#         50*flow[pp_oil,bel,92] + 50*flow[pp_oil,bel,93] +
#         50*flow[pp_oil,bel,94] + 50*flow[pp_oil,bel,95] +
#         50*flow[pp_oil,bel,96] + 50*flow[pp_oil,bel,97] +
#         50*flow[pp_oil,bel,98] + 50*flow[pp_oil,bel,99] +
#         50*flow[pp_oil,bel,100] + 50*flow[pp_oil,bel,101] +
#         50*flow[pp_oil,bel,102] + 50*flow[pp_oil,bel,103] +
#         50*flow[pp_oil,bel,104] + 50*flow[pp_oil,bel,105] +
#         50*flow[pp_oil,bel,106] + 50*flow[pp_oil,bel,107] +
#         50*flow[pp_oil,bel,108] + 50*flow[pp_oil,bel,109] +
#         50*flow[pp_oil,bel,110] + 50*flow[pp_oil,bel,111] +
#         50*flow[pp_oil,bel,112] + 50*flow[pp_oil,bel,113] +
#         50*flow[pp_oil,bel,114] + 50*flow[pp_oil,bel,115] +
#         50*flow[pp_oil,bel,116] + 50*flow[pp_oil,bel,117] +
#         50*flow[pp_oil,bel,118] + 50*flow[pp_oil,bel,119] +
#         50*flow[pp_oil,bel,120] + 50*flow[pp_oil,bel,121] +
#         50*flow[pp_oil,bel,122] + 50*flow[pp_oil,bel,123] +
#         50*flow[pp_oil,bel,124] + 50*flow[pp_oil,bel,125] +
#         50*flow[pp_oil,bel,126] + 50*flow[pp_oil,bel,127] +
#         50*flow[pp_oil,bel,128] + 50*flow[pp_oil,bel,129] +
#         50*flow[pp_oil,bel,130] + 50*flow[pp_oil,bel,131] +
#         50*flow[pp_oil,bel,132] + 50*flow[pp_oil,bel,133] +
#         50*flow[pp_oil,bel,134] + 50*flow[pp_oil,bel,135] +
#         50*flow[pp_oil,bel,136] + 50*flow[pp_oil,bel,137] +
#         50*flow[pp_oil,bel,138] + 50*flow[pp_oil,bel,139] +
#         50*flow[pp_oil,bel,140] + 50*flow[pp_oil,bel,141] +
#         50*flow[pp_oil,bel,142] + 50*flow[pp_oil,bel,143] +
#         50*flow[pp_oil,bel,144] + 50*flow[pp_oil,bel,145] +
#         50*flow[pp_oil,bel,146] + 50*flow[pp_oil,bel,147] +
#         50*flow[pp_oil,bel,148] + 50*flow[pp_oil,bel,149] +
#         50*flow[pp_oil,bel,150] + 50*flow[pp_oil,bel,151] +
#         50*flow[pp_oil,bel,152] + 50*flow[pp_oil,bel,153] +
#         50*flow[pp_oil,bel,154] + 50*flow[pp_oil,bel,155] +
#         50*flow[pp_oil,bel,156] + 50*flow[pp_oil,bel,157] +
#         50*flow[pp_oil,bel,158] + 50*flow[pp_oil,bel,159] +
#         50*flow[pp_oil,bel,160] + 50*flow[pp_oil,bel,161] +
#         50*flow[pp_oil,bel,162] + 50*flow[pp_oil,bel,163] +
#         50*flow[pp_oil,bel,164] + 50*flow[pp_oil,bel,165] +
#         50*flow[pp_oil,bel,166] + 50*flow[pp_oil,bel,167] +
#         50*flow[pp_oil,bel,168] + 50*flow[pp_oil,bel,169] +
#         50*flow[pp_oil,bel,170] + 50*flow[pp_oil,bel,171] +
#         50*flow[pp_oil,bel,172] + 50*flow[pp_oil,bel,173] +
#         50*flow[pp_oil,bel,174] + 50*flow[pp_oil,bel,175] +
#         50*flow[pp_oil,bel,176] + 50*flow[pp_oil,bel,177] +
#         50*flow[pp_oil,bel,178] + 50*flow[pp_oil,bel,179] +
#         50*flow[pp_oil,bel,180] + 50*flow[pp_oil,bel,181] +
#         50*flow[pp_oil,bel,182] + 50*flow[pp_oil,bel,183] +
#         50*flow[pp_oil,bel,184] + 50*flow[pp_oil,bel,185] +
#         50*flow[pp_oil,bel,186] + 50*flow[pp_oil,bel,187] +
#         50*flow[pp_oil,bel,188] + 50*flow[pp_oil,bel,189] +
#         50*flow[pp_oil,bel,190] + 50*flow[pp_oil,bel,191] +
#         50*flow[pp_oil,bel,192] + 50*flow[pp_oil,bel,193] +
#         50*flow[pp_oil,bel,194] + 50*flow[pp_oil,bel,195] +
#         50*flow[pp_oil,bel,196] + 50*flow[pp_oil,bel,197] +
#         50*flow[pp_oil,bel,198] + 50*flow[pp_oil,bel,199] +
#         50*flow[pp_oil,bel,200] + 50*flow[pp_oil,bel,201] +
#         50*flow[pp_oil,bel,202] + 50*flow[pp_oil,bel,203] +
#         50*flow[pp_oil,bel,204] + 50*flow[pp_oil,bel,205] +
#         50*flow[pp_oil,bel,206] + 50*flow[pp_oil,bel,207] +
#         50*flow[pp_oil,bel,208] + 50*flow[pp_oil,bel,209] +
#         50*flow[pp_oil,bel,210] + 50*flow[pp_oil,bel,211] +
#         50*flow[pp_oil,bel,212] + 50*flow[pp_oil,bel,213] +
#         50*flow[pp_oil,bel,214] + 50*flow[pp_oil,bel,215] +
#         50*flow[pp_oil,bel,216] + 50*flow[pp_oil,bel,217] +
#         50*flow[pp_oil,bel,218] + 50*flow[pp_oil,bel,219] +
#         50*flow[pp_oil,bel,220] + 50*flow[pp_oil,bel,221] +
#         50*flow[pp_oil,bel,222] + 50*flow[pp_oil,bel,223] +
#         50*flow[pp_oil,bel,224] + 50*flow[pp_oil,bel,225] +
#         50*flow[pp_oil,bel,226] + 50*flow[pp_oil,bel,227] +
#         50*flow[pp_oil,bel,228] + 50*flow[pp_oil,bel,229] +
#         50*flow[pp_oil,bel,230] + 50*flow[pp_oil,bel,231] +
#         50*flow[pp_oil,bel,232] + 50*flow[pp_oil,bel,233] +
#         50*flow[pp_oil,bel,234] + 50*flow[pp_oil,bel,235] +
#         50*flow[pp_oil,bel,236] + 50*flow[pp_oil,bel,237] +
#         50*flow[pp_oil,bel,238] + 50*flow[pp_oil,bel,239])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-c3ecbcf9bc11> in <module>
#       1 energysystem.results['main'] = outputlib.processing.results(optimization_model)
# ----> 2 energysystem.results['meta'] = outputlib.processing.meta_results(optimization_model)
#
# ~/Schreibtisch/oemof/oemof/outputlib/processing.py in meta_results(om, undefined)
#     197     dict
#     198     """
# --> 199     meta_res = {'objective': om.objective()}
#     200
#     201     for k1 in ['Problem', 'Solver']:
#
# ~/Schreibtisch/p3/lib/python3.6/site-packages/pyomo/core/base/expression.py in __call__(self, exception)
#      53         if self.expr is None:
#      54             return None
# ---> 55         return self.expr(exception=exception)
#      56
#      57     #
#
# ~/Schreibtisch/p3/lib/python3.6/site-packages/pyomo/core/kernel/expr_coopr3.py in __call__(self, exception)
#     206             return self._apply_operation(
#     207                 self._evaluate_arglist(self._args,
# --> 208                                        exception=exception))
#     209         except (ValueError, TypeError):
#     210             if exception:
#
# ~/Schreibtisch/p3/lib/python3.6/site-packages/pyomo/core/kernel/expr_coopr3.py in _apply_operation(self, values)
#     810     def _apply_operation(self, values):
#     811         """Evaluate the expression"""
# --> 812         return sum(c*next(values) for c in self._coef) + self._const
#     813
#     814 class _GetItemExpression(_ExpressionBase):
#
# ~/Schreibtisch/p3/lib/python3.6/site-packages/pyomo/core/kernel/expr_coopr3.py in <genexpr>(.0)
#     810     def _apply_operation(self, values):
#     811         """Evaluate the expression"""
# --> 812         return sum(c*next(values) for c in self._coef) + self._const
#     813
#     814 class _GetItemExpression(_ExpressionBase):
#
# ~/Schreibtisch/p3/lib/python3.6/site-packages/pyomo/core/kernel/expr_coopr3.py in _evaluate_arglist(self, arglist, exception)
#     215         for arg in arglist:
#     216             try:
# --> 217                 yield value(arg, exception=exception)
#     218             except Exception:
#     219                 if exception:
#
# ~/Schreibtisch/p3/lib/python3.6/site-packages/pyomo/core/kernel/numvalue.py in value(obj, exception)
#     168     if exception and (tmp is None):
#     169         raise ValueError("No value for uninitialized NumericValue object %s"
# --> 170                          % (obj.name,))
#     171     return tmp
#     172
#
# ValueError: No value for uninitialized NumericValue object flow[pp_coal,bel,0]

# %%
string_results = outputlib.views.convert_keys_to_strings(energysystem.results['main'])

# %% [markdown]
# ### Save results - Dump the energysystem (to ~/home/user/.oemof by default)
# Specify path and filename if you do not want to overwrite

# %%
energysystem.dump(dpath=None, filename=None)
